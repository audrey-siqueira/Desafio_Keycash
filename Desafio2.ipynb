# %% [markdown]
# <a href="https://colab.research.google.com/github/audrey-siqueira/Desafio_Keycash/blob/main/Desafio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalando o PYCARET

# %% [markdown]
# Nosso projeto será baseado na biblioteca PYCARET, devido essa ser de fácil manipulação e ágil para conseguir o objetivo de precificar os imóveis.

# %%
# instalando a biblioteca
# !pip install pycaret -q
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
# configurando PyCaret para o Colab
from pycaret.utils import enable_colab 
enable_colab()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Colab mode enabled.

# %% [markdown]
# ## Coletando os dados

# %% [markdown]
# O arquivo .csv contendo os dados é importado.
#
# Os valores do cabeçalho do banco de dados e como são distribuídos podem ser visualizados na imagem abaixo:

# %%
# importando os dados
dataset= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Keycash/Desafio2_input.csv',sep = ';')
dataset.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#    Id Zona   Area  Qualidade  ...  Comodos Lareiras  Garagem   Preco
# 0   1   RL   9600          6  ...        6        1        2  181500
# 1   2   RL  14115          5  ...        5        0        2  143000
# 2   3   RL  11200          5  ...        5        0        1  129500
# 3   4   RL  12968          5  ...        4        0        1  144000
# 4   5   RL  10920          6  ...        5        1        1  157000
#
# [5 rows x 13 columns]

# %%
# verificando o número de linhas e colunas do dataset
dataset.shape
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# (629, 13)

# %% [markdown]
# ## Dividindo os dados

# %% [markdown]
# A fim de demonstrar a função predict_model () em dados ocultos, uma amostra de 63 registros foi retida do conjunto de dados original para ser usada para previsões.
#
# Isso não deve ser confundido com uma divisão de treinamento / teste, pois essa divisão em particular é realizada para simular um cenário da vida real.
#
# Outra maneira de pensar sobre isso é que esses 63 registros não estão disponíveis no momento em que o experimento de aprendizado de máquina foi realizado.

# %%
# separando os dados em teste e treino
data = dataset.sample(frac=0.9)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Data for Modeling: (566, 13)
# Unseen Data For Predictions: (63, 13)

# %% [markdown]
# ## Configurando os dados no PyCaret

# %% [markdown]
# Importando os pacotes necessários para se usar o PYCARET para Regressões.

# %%
# importando os pacotes necessários
from pycaret.regression import *
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %% [markdown]
# Como estamos objetivando a precificação dos imóveis, a coluna de Preço será nossa varíavel dependente.
#
# A coluna de ID será excluída por não ter relevância no Preço para o treinamento dos modelos.
#
# As demais colunas com variáveis independentes foram incluidas no treinamento,  obtendo o conjunto de dados final.
#
# O PYCARET se encarrega de dividir as variáveis entre numéricas e categóricas, incluir valores faltantes, além de registrar outros diversos parâmetros do dataset, como listado abaixo:

# %%
reg = setup(data = data, target = 'Preco', ignore_features = ['Id']	)
# Out:
#                                Description             Value
# 0                               session_id              4302
# 1                                   Target             Preco
# 2                            Original Data         (566, 13)
# 3                           Missing Values             False
# 4                         Numeric Features                 2
# 5                     Categorical Features                 9
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set         (396, 29)
# 10                    Transformed Test Set         (170, 29)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU             False
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              dfcb
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize             False
# 28                        Normalize Method              None
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity             False
# 41             Multicollinearity Threshold              None
# 42                              Clustering             False
# 43                    Clustering Iteration              None
# 44                     Polynomial Features             False
# 45                       Polynomial Degree              None
# 46                    Trignometry Features             False
# 47                    Polynomial Threshold              None
# 48                          Group Features             False
# 49                       Feature Selection             False
# 50            Features Selection Threshold              None
# 51                     Feature Interaction             False
# 52                           Feature Ratio             False
# 53                   Interaction Threshold              None
# 54                        Transform Target             False
# 55                 Transform Target Method           box-cox

# %% [markdown]
# ## Comparando os modelos para escolher o melhor

# %% [markdown]
# O PYCARET possui diversos modelos de regressão (aproximadamente 20 diferentes tipos de algoritmos de regressão).
#
# Comparando os modelos baseados em suas acuracidades envolvendo desde R quadrado (R2) até Erro Absoluto Médio (MAE), o PYCARET divide os modelos em uma lista de ordem de possível eficiência para nosso projeto, como demonstrado na lista abaixo.

# %%
# best = compare_models()
best = compare_models(sort='R2')
# Out:
#                                     Model           MAE           MSE  \
# ridge                    Ridge Regression  1.142520e+04  2.195507e+08
# llar         Lasso Least Angle Regression  1.147803e+04  2.208359e+08
# lasso                    Lasso Regression  1.147911e+04  2.209968e+08
# lr                      Linear Regression  1.148131e+04  2.211204e+08
# rf                Random Forest Regressor  1.163452e+04  2.362650e+08
# catboost               CatBoost Regressor  1.175297e+04  2.409128e+08
# gbr           Gradient Boosting Regressor  1.173098e+04  2.451496e+08
# lightgbm  Light Gradient Boosting Machine  1.205449e+04  2.459695e+08
# ada                    AdaBoost Regressor  1.296854e+04  2.781076e+08
# en                            Elastic Net  1.372360e+04  2.952996e+08
# et                  Extra Trees Regressor  1.272120e+04  2.873363e+08
# xgboost         Extreme Gradient Boosting  1.307222e+04  3.001235e+08
# huber                     Huber Regressor  1.398826e+04  3.312092e+08
# omp           Orthogonal Matching Pursuit  1.580516e+04  4.133868e+08
# dt                Decision Tree Regressor  1.577170e+04  4.361472e+08
# br                         Bayesian Ridge  2.189713e+04  6.860711e+08
# knn                 K Neighbors Regressor  2.211737e+04  7.516656e+08
# par          Passive Aggressive Regressor  3.988739e+04  2.898418e+09
# lar                Least Angle Regression  1.638510e+07  3.940303e+15
#
#                   RMSE            R2   RMSLE      MAPE  TT (Sec)
# ridge     1.465258e+04  6.925000e-01  0.1043    0.0814     0.013
# llar      1.470543e+04  6.903000e-01  0.1046    0.0818     0.018
# lasso     1.471006e+04  6.900000e-01  0.1047    0.0818     0.019
# lr        1.471449e+04  6.898000e-01  0.1047    0.0818     0.013
# rf        1.522670e+04  6.676000e-01  0.1098    0.0840     0.486
# catboost  1.536551e+04  6.619000e-01  0.1095    0.0842     1.041
# gbr       1.549560e+04  6.545000e-01  0.1105    0.0843     0.069
# lightgbm  1.554154e+04  6.520000e-01  0.1105    0.0862     0.036
# ada       1.654377e+04  6.162000e-01  0.1178    0.0919     0.089
# en        1.702458e+04  5.939000e-01  0.1223    0.0984     0.015
# et        1.679295e+04  5.880000e-01  0.1216    0.0912     0.447
# xgboost   1.719737e+04  5.708000e-01  0.1224    0.0930     1.618
# huber     1.762449e+04  5.390000e-01  0.1264    0.1008     0.039
# omp       2.029627e+04  4.171000e-01  0.1451    0.1140     0.013
# dt        2.081628e+04  3.659000e-01  0.1513    0.1131     0.014
# br        2.603910e+04  6.310000e-02  0.1825    0.1562     0.014
# knn       2.722538e+04 -2.740000e-02  0.1885    0.1564     0.062
# par       4.576096e+04 -3.200500e+00  0.2961    0.2664     0.016
# lar       1.988067e+07 -7.073984e+06  0.8542  110.4233     0.021

# %% [markdown]
# ## Criando o modelo escolhido

# %% [markdown]
# O algoritmo de regressão que obteve o melhor desempenho baseado no R quadrado foi o de Ridge Regression.
#
# A função abaixo treina e avalia o desempenho do determinado modelo escolhido.
#
# É possível visualizar o comportamento do modelo para diferentes Folds.

# %%
# treinando o modelo Gradient Boosting Regressor
modelo = create_model('ridge')
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      9433.6387  1.640711e+08  12809.0225  0.7402  0.0901  0.0665
# 1     10067.2715  1.864144e+08  13653.3652  0.8170  0.1087  0.0782
# 2      8944.5986  1.303318e+08  11416.2939  0.7356  0.0760  0.0591
# 3     10470.2969  1.567292e+08  12519.1514  0.7806  0.0887  0.0734
# 4     11298.6670  2.158361e+08  14691.3623  0.7370  0.1037  0.0836
# 5     13446.3096  2.693791e+08  16412.7734  0.5744  0.1129  0.0918
# 6     13394.6924  3.639019e+08  19076.2109  0.4384  0.1420  0.1071
# 7     11613.4277  2.355762e+08  15348.4902  0.7737  0.1150  0.0850
# 8     10805.9971  1.877011e+08  13700.4062  0.6630  0.0902  0.0710
# 9     14777.0977  2.855662e+08  16898.7031  0.6651  0.1155  0.0986
# Mean  11425.1997  2.195507e+08  14652.5779  0.6925  0.1043  0.0814
# SD     1803.0353  6.711613e+07   2202.8729  0.1078  0.0179  0.0141

# %% [markdown]
# Os valores dos parâmetros do algoritmo escolhido para o treinamento podem visualizados abaixo:

# %%
# verificando os parâmetros
print(modelo)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=4302, solver='auto', tol=0.001)

# %% [markdown]
# ## Otimizando o modelo com o ajuste de hiperparâmetros

# %% [markdown]
# O PyCaret também é extremamente fácil fazer a otimização dos parâmetros para melhorar o modelo. Basta utilizar o método `tune_model` passando como parâmetro o modelo a ser otimizado e a métrica pela qual otimizar.

# %%
# tuning de parâmetros
tuned_modelo = tune_model(modelo)
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0      9316.0215  1.602159e+08  12657.6406  0.7463  0.0886  0.0656
# 1     10196.1094  1.888936e+08  13743.8584  0.8146  0.1095  0.0792
# 2      8771.3125  1.276307e+08  11297.3750  0.7411  0.0755  0.0581
# 3     10418.1982  1.554270e+08  12467.0352  0.7825  0.0883  0.0730
# 4     11157.6777  2.143454e+08  14640.5391  0.7388  0.1036  0.0829
# 5     13420.5293  2.691148e+08  16404.7188  0.5748  0.1128  0.0916
# 6     13337.3730  3.614443e+08  19011.6895  0.4422  0.1416  0.1066
# 7     11585.4219  2.341105e+08  15300.6709  0.7751  0.1149  0.0851
# 8     10846.4004  1.897485e+08  13774.9248  0.6593  0.0905  0.0711
# 9     14919.5674  2.911961e+08  17064.4688  0.6585  0.1162  0.0994
# Mean  11396.8611  2.192127e+08  14636.2921  0.6933  0.1041  0.0813
# SD     1851.7299  6.772828e+07   2234.1976  0.1077  0.0181  0.0143

# %% [markdown]
# Os valores dos parâmetros do algoritmo escolhido após a otimização do modelo podem visualizados abaixo:

# %%
# veriificando os parâmetros
print(tuned_modelo)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Ridge(alpha=2.09, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=4302, solver='auto', tol=0.001)

# %% [markdown]
# ## Plotar o Modelo

# %% [markdown]
# Representação gráfica do modelo para diferentes tipos de métricas.

# %%
# avaliando o modelo
evaluate_model(tuned_modelo)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## Prevendo os resultados do conjunto de testes com o modelo otimizado

# %% [markdown]
# Agora que já conseguimos criar, treinar e avaliar nosso modelo, é hora de fazer previsões no nosso conjunto de testes.

# %%
# fazendo previsões
predict_model(tuned_modelo)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#               Model           MAE          MSE  ...      R2   RMSLE    MAPE
# 0  Ridge Regression  11830.207031  241328928.0  ...  0.7188  0.1136  0.0876
#
# [1 rows x 7 columns]
#         Area  AnoConstrucao  Zona_RL  ...  Garagem_3     Preco        Label
# 0     3072.0         2004.0      0.0  ...        0.0  178740.0  165518.7500
# 1     3922.0         2006.0      1.0  ...        1.0  172500.0  177387.3125
# 2     1680.0         1971.0      0.0  ...        0.0   91500.0  101301.0000
# 3     8461.0         2005.0      1.0  ...        0.0  163990.0  176402.3125
# 4    15578.0         2006.0      1.0  ...        0.0  172785.0  186536.0625
# ..       ...            ...      ...  ...        ...       ...          ...
# 165  12886.0         1963.0      1.0  ...        0.0  175000.0  164954.1250
# 166  11310.0         1954.0      1.0  ...        0.0  140000.0  151135.9375
# 167  14000.0         1950.0      1.0  ...        0.0  158500.0  148397.6875
# 168   8335.0         1954.0      1.0  ...        0.0   93000.0  116397.1250
# 169   7837.0         1993.0      1.0  ...        0.0  178000.0  175269.3125
#
# [170 rows x 31 columns]

# %% [markdown]
# ## Finalizar o Modelo

# %% [markdown]
# A finalização do modelo é a última etapa do experimento.
#
# Esse fluxo acabará nos levando  ao melhor modelo para uso ao fazer previsões sobre dados novos e ocultos.
#
# A função finalize_model () ajusta o modelo ao conjunto de dados completo, incluindo a amostra de teste (30% neste caso).
#
# Uma vez que o modelo é finalizado usando finalize_model (), todo o conjunto de dados incluindo o conjunto de teste é usado para treinamento.
#
# Como tal, se esse modelo for usado para previsões com os dados de teste após o uso de finalize_model (), as informações podem ser enganosas, pois você está tentando prever os mesmos dados que foram usados para modelagem.
#
# A fim de demonstrar este ponto apenas, usaremos os dados ocultos no início do tutorial para testar esse modelo finalizado.

# %%
# finalizando o modelo
final_modelo = finalize_model(tuned_modelo)
print(final_modelo)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Ridge(alpha=2.09, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=4302, solver='auto', tol=0.001)

# %% [markdown]
# Abaixo um exemplo que pode nos levar ao engano.
#
# Usar os dados de teste para validar esse modelo finalizado, que usou os dados de teste para treinamento, pode causar um engano, por isso no próximo tópico vamos usar os dados ocultos para validar esse modelo.

# %%
# fazendo previsões com conjunto de testes a partir do modelo finalizado
predict_model(final_modelo)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#               Model           MAE          MSE  ...      R2   RMSLE    MAPE
# 0  Ridge Regression  11226.986328  221727344.0  ...  0.7417  0.1085  0.0822
#
# [1 rows x 7 columns]
#         Area  AnoConstrucao  Zona_RL  ...  Garagem_3     Preco        Label
# 0     3072.0         2004.0      0.0  ...        0.0  178740.0  166173.9375
# 1     3922.0         2006.0      1.0  ...        1.0  172500.0  175883.0000
# 2     1680.0         1971.0      0.0  ...        0.0   91500.0  100524.5625
# 3     8461.0         2005.0      1.0  ...        0.0  163990.0  176954.7500
# 4    15578.0         2006.0      1.0  ...        0.0  172785.0  183849.1875
# ..       ...            ...      ...  ...        ...       ...          ...
# 165  12886.0         1963.0      1.0  ...        0.0  175000.0  164873.4375
# 166  11310.0         1954.0      1.0  ...        0.0  140000.0  151441.9375
# 167  14000.0         1950.0      1.0  ...        0.0  158500.0  149128.8750
# 168   8335.0         1954.0      1.0  ...        0.0   93000.0  116397.9375
# 169   7837.0         1993.0      1.0  ...        0.0  178000.0  174480.3750
#
# [170 rows x 31 columns]

# %% [markdown]
# ##Prevendo os resultados do conjunto de dados ocultos com o modelo finalizado

# %% [markdown]
# A função predict_model () também é usada para prever o conjunto de dados ocultos.
#
# data_unseen é a variável criada no início do tutorial e contém 10% do conjunto de dados original que nunca foi exposto ao PyCaret.

# %%
unseen_predictions = predict_model(final_modelo, data=data_unseen)
unseen_predictions.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#    Id Zona   Area  Qualidade  ...  Lareiras Garagem   Preco        Label
# 0  11   RL   7200          5  ...         0       2  134800  124606.1875
# 1  15   RL   8532          5  ...         1       2  153000  139627.8750
# 2  16   RL   7922          5  ...         0       1  109000  116721.5625
# 3  23   RL  13869          6  ...         0       2  177000  178458.4375
# 4  28   RL  13072          6  ...         0       2  158000  163585.8750
#
# [5 rows x 14 columns]

# %%
from pycaret.utils import check_metric
check_metric(unseen_predictions.Preco, unseen_predictions.Label, 'R2')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# 0.6457

# %% [markdown]
# ## Salvando o Modelo

# %% [markdown]
# Com nossa fase de experimentos finalizada, o PyCaret também facilita a nossa vida na hora do deploy, sendo bastante simples o processo de salvar o modelo para uso posterior.
#
# Para isso, vamos utilizar o método `save_model`, passando como parâmetro o modelo e o nome do arquivo a ser salvo.

# %%
# salvando o modelo
save_model(final_modelo, "Modelo (Precificando Imóveis")
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['Id'], id_columns=[],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='Preco',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                  ('dummy', Dummify(target='Preco')),
#                  ('fix_perfect', Remove_100(target='Preco')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   Ridge(alpha=2.09, copy_X=True, fit_intercept=True,
#                         max_iter=None, normalize=False, random_state=4302,
#                         solver='auto', tol=0.001)]],
#           verbose=False), 'Modelo (Precificando Imóveis.pkl')

# %% [markdown]
# ## Carregando um Modelo

# %% [markdown]
# Para carregar o modelo salvo previamente no PYCARET vamos utilizar o método `load_model`, passando como parâmetro o nome do arquivo do modelo.

# %%
#carregando o modelo
saved_final_modelo = load_model('Modelo (Precificando Imóveis')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# Com o modelo carregado, é fácil fazer novas previsões com ele, assim como fizemos ao finalizar nosso modelo.

# %%
# fazendo previsões
new_prediction = predict_model(saved_final_modelo, data=data_unseen)
new_prediction.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#    Id Zona   Area  Qualidade  ...  Lareiras Garagem   Preco        Label
# 0  11   RL   7200          5  ...         0       2  134800  124606.1875
# 1  15   RL   8532          5  ...         1       2  153000  139627.8750
# 2  16   RL   7922          5  ...         0       1  109000  116721.5625
# 3  23   RL  13869          6  ...         0       2  177000  178458.4375
# 4  28   RL  13072          6  ...         0       2  158000  163585.8750
#
# [5 rows x 14 columns]

# %% [markdown]
# Observe que os resultados de unseen_predictions e new_prediction são idênticos.

# %%
# avaliando o modelo
from pycaret.utils import check_metric
check_metric(new_prediction.Preco, new_prediction.Label, 'R2')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# 0.6457
